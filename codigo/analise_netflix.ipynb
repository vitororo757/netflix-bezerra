# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
viewing = [
    '../dados/GabrielKoji/ViewingActivityKoji.csv',
    '../dados/JoãoVargas/ViewingActivityJoao.csv',
    '../dados/RafaelCruz/ViewingActivityRafa.csv',
    '../dados/RaissaCasale/ViewingActivityRaissa.csv',
    '../dados/RyanLionel/ViewingActivityRyan.csv'
]

df = pd.concat([pd.read_csv(f) for f in viewing], ignore_index=True) 

display(df)
# Out:
#         Duration           Start Time Profile Name      Country  Bookmark  \
# 0       00:00:05  2026-01-30 14:59:45        Extra  BR (Brazil)  00:56:20
# 1       00:05:47  2026-01-30 14:39:46        Extra  BR (Brazil)  00:54:40
# 2       00:40:58  2026-01-30 09:18:13        Extra  BR (Brazil)  00:40:09
# 3       00:00:38  2026-01-30 08:40:42        Extra  BR (Brazil)  00:25:59
# 4       00:06:37  2026-01-30 01:26:09        Extra  BR (Brazil)  00:20:14
# ...          ...                  ...          ...          ...       ...
# 108413  00:00:30  2015-12-04 08:56:45         Ryan  BR (Brazil)  00:13:20
# 108414  00:00:55  2015-12-04 08:55:16         Ryan  BR (Brazil)  00:29:19
# 108415  00:07:48  2015-12-04 08:45:39         Ryan  BR (Brazil)  00:00:23
# 108416  00:05:08  2015-12-04 08:39:27         Ryan  BR (Brazil)  00:00:00
# 108417  00:07:34  2015-12-03 22:45:28         Ryan  BR (Brazil)  00:07:34
#
#         Latest Bookmark Supplemental Video Type Attributes  \
# 0              00:56:20                     NaN        NaN
# 1       Not latest view                     NaN        NaN
# 2       Not latest view                     NaN        NaN
# 3              00:25:59                     NaN        NaN
# 4              00:20:14                     NaN        NaN
# ...                 ...                     ...        ...
# 108413         00:13:20                     NaN        NaN
# 108414  Not latest view                     NaN        NaN
# 108415  Not latest view                     NaN        NaN
# 108416  Not latest view                     NaN        NaN
# 108417  Not latest view                     NaN        NaN
#
#                         Device Type  \
# 0       DefaultWidevineAndroidPhone
# 1       DefaultWidevineAndroidPhone
# 2       DefaultWidevineAndroidPhone
# 3       DefaultWidevineAndroidPhone
# 4               Chrome OS (Cadmium)
# ...                             ...
# 108413                       Mobile
# 108414                       Mobile
# 108415                       Mobile
# 108416                       Mobile
# 108417                       Mobile
#
#                                                     Title
# 0       Bridgerton: Temporada 1: Diamante raro (episód...
# 1       Bridgerton: Temporada 1: Diamante raro (episód...
# 2       Bridgerton: Temporada 1: Diamante raro (episód...
# 3       Bridgerton: Temporada 4: Um Perfeito Cavalheir...
# 4       Dr. House: Temporada 5: Simple Explanation (ep...
# ...                                                   ...
# 108413                                Zé Colmeia: O Filme
# 108414                Os Pinguins de Madagascar – O Filme
# 108415                                        Toy Story 2
# 108416                                        Toy Story 3
# 108417                       Hermanoteu na Terra de Godah
#
# [108418 rows x 10 columns]

# %%
#eliminar colunas desnecessárias
df.drop(["Profile Name", "Attributes", "Supplemental Video Type", "Device Type",
"Bookmark", "Latest Bookmark", "Country"], axis=1, inplace=True)
df.head()
# Out:
#    Duration           Start Time  \
# 0  00:00:05  2026-01-30 14:59:45
# 1  00:05:47  2026-01-30 14:39:46
# 2  00:40:58  2026-01-30 09:18:13
# 3  00:00:38  2026-01-30 08:40:42
# 4  00:06:37  2026-01-30 01:26:09
#
#                                                Title
# 0  Bridgerton: Temporada 1: Diamante raro (episód...
# 1  Bridgerton: Temporada 1: Diamante raro (episód...
# 2  Bridgerton: Temporada 1: Diamante raro (episód...
# 3  Bridgerton: Temporada 4: Um Perfeito Cavalheir...
# 4  Dr. House: Temporada 5: Simple Explanation (ep...

# %%
df.columns = ['Duration','Start_Time', 'Title']
df.isna().values.any()
df.dtypes
# Out:
# Duration      object
# Start_Time    object
# Title         object
# dtype: object

# %%
df['Start_Time'] = pd.to_datetime(
    df['Start_Time'],
    format='mixed',
    dayfirst=True,
    utc=True
)

df.dtypes
# Out:
# Duration                   object
# Start_Time    datetime64[ns, UTC]
# Title                      object
# dtype: object

# %%
# transformar Date em índice
df = df.set_index('Start_Time')

# converter o fuso horário
df.index = df.index.tz_convert('America/Sao_Paulo')

#Voltar Date para coluna
df = df.reset_index()

df.head()
# Out:
#                  Start_Time  Duration  \
# 0 2026-01-30 11:59:45-03:00  00:00:05
# 1 2026-01-30 11:39:46-03:00  00:05:47
# 2 2026-01-30 06:18:13-03:00  00:40:58
# 3 2026-01-30 05:40:42-03:00  00:00:38
# 4 2026-01-29 22:26:09-03:00  00:06:37
#
#                                                Title
# 0  Bridgerton: Temporada 1: Diamante raro (episód...
# 1  Bridgerton: Temporada 1: Diamante raro (episód...
# 2  Bridgerton: Temporada 1: Diamante raro (episód...
# 3  Bridgerton: Temporada 4: Um Perfeito Cavalheir...
# 4  Dr. House: Temporada 5: Simple Explanation (ep...

# %%
df['Duration'] = pd.to_timedelta(df['Duration'])
df.dtypes
# Out:
# Start_Time    datetime64[ns, America/Sao_Paulo]
# Duration                        timedelta64[ns]
# Title                                    object
# dtype: object

# %%
#criando novas colunar 'Temporada' e 'Episodio' utilizando a coluna 'Title'
df[['Title_Name', 'Temporada', 'Episodio']] = df['Title'].str.split(': ',n=2, expand=True)

df.drop('Title', axis=1, inplace=True)

df.head()
# Out:
#                  Start_Time        Duration  Title_Name    Temporada  \
# 0 2026-01-30 11:59:45-03:00 0 days 00:00:05  Bridgerton  Temporada 1
# 1 2026-01-30 11:39:46-03:00 0 days 00:05:47  Bridgerton  Temporada 1
# 2 2026-01-30 06:18:13-03:00 0 days 00:40:58  Bridgerton  Temporada 1
# 3 2026-01-30 05:40:42-03:00 0 days 00:00:38  Bridgerton  Temporada 4
# 4 2026-01-29 22:26:09-03:00 0 days 00:06:37   Dr. House  Temporada 5
#
#                               Episodio
# 0           Diamante raro (episódio 1)
# 1           Diamante raro (episódio 1)
# 2           Diamante raro (episódio 1)
# 3  Um Perfeito Cavalheiro (episódio 4)
# 4     Simple Explanation (episódio 20)

# %%
#criando novas colunas de 'Mês' e 'Hora' utilizando a coluna 'Start_Time'
df['Mês'] = df['Start_Time'].dt.weekday

df['Hora'] = df['Start_Time'].dt.hour

df.head()
# Out:
#                  Start_Time        Duration  Title_Name    Temporada  \
# 0 2026-01-30 11:59:45-03:00 0 days 00:00:05  Bridgerton  Temporada 1
# 1 2026-01-30 11:39:46-03:00 0 days 00:05:47  Bridgerton  Temporada 1
# 2 2026-01-30 06:18:13-03:00 0 days 00:40:58  Bridgerton  Temporada 1
# 3 2026-01-30 05:40:42-03:00 0 days 00:00:38  Bridgerton  Temporada 4
# 4 2026-01-29 22:26:09-03:00 0 days 00:06:37   Dr. House  Temporada 5
#
#                               Episodio  Mês  Hora
# 0           Diamante raro (episódio 1)    4    11
# 1           Diamante raro (episódio 1)    4    11
# 2           Diamante raro (episódio 1)    4     6
# 3  Um Perfeito Cavalheiro (episódio 4)    4     5
# 4     Simple Explanation (episódio 20)    3    22

# %%
#Quantidade de plays em cada serie
df['Title_Name'].value_counts()
# Out:
# Title_Name
# Unknown Title            1411
# Trailer                  1251
# Vikings                   811
# Temporada 1 (Clipe)       779
# Gilmore Girls             595
#                          ...
# Morte Súbita                1
# Mais forte que bombas       1
# Sexo sem Compromisso        1
# VIPs                        1
# Skyline                     1
# Name: count, Length: 8958, dtype: int64

# %%
#top 10 series mais assistidas
top_10_series = df.groupby(['Title_Name']).agg({'Duration': 'sum'}).sort_values(by = 'Duration', ascending=False).head(10)
top_10_series.head(10)
# Out:
#                            Duration
# Title_Name
# Vikings            10 days 23:03:32
# Stranger Things     9 days 23:00:15
# Alquimia das Almas  7 days 10:23:52
# Prison Break        6 days 21:54:54
#                     6 days 21:34:06
# Grimm               6 days 18:21:34
# Dr. House           6 days 10:11:14
# The Good Wife       6 days 05:07:23
# Teen Wolf           6 days 01:32:10
# Dexter              5 days 20:35:44

# %%
#top 10 filmes mais assistidos
top_10_filmes = df[df['Temporada'].isna()].groupby(['Title_Name']).agg({'Duration': 'sum'}).sort_values(by = 'Duration', ascending=False).head(10)
top_10_filmes.head(10)
# Out:
#                                 Duration
# Title_Name
# Unknown Title            4 days 17:18:13
# Guerreiras do K-Pop      0 days 23:21:29
# Alerta Vermelho          0 days 18:05:41
# O Mundo Depois de Nós    0 days 13:14:35
# O Protetor               0 days 12:19:01
# The Old Guard            0 days 12:18:32
# Jason Bourne             0 days 12:08:31
# Jake Paul vs. Mike Tyson 0 days 10:50:29
# Rebel Ridge              0 days 10:07:27
# A Mãe                    0 days 10:04:47

# %%
#Quantidade totais de midia assistida
total_duration = df['Duration'].sum()
print(f'Tempo total assistido: {total_duration}')

#Quantidade de midia assistida por mês
df['Month'] = df['Start_Time'].dt.month
media_por_mes = df.groupby('Month')['Title_Name'].nunique()
print(media_por_mes)

#Quantidade totais de midias assistidas
total_titles = df['Title_Name'].nunique()
print(f'Total de títulos assistidos: {total_titles}')
# Out:
# Tempo total assistido: 1305 days 09:06:45
# Month
# 1     2007
# 2     1031
# 3     1328
# 4     1189
# 5     1126
# 6     1098
# 7     1383
# 8     1381
# 9     1362
# 10    1411
# 11    1547
# 12    1734
# Name: Title_Name, dtype: int64
# Total de títulos assistidos: 8958
